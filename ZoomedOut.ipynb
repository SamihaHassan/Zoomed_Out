# %%
import cv2

# %%
from deepface import DeepFace

# %%
img = cv2.imread('happyme.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions  = DeepFace.analyze(img)
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING:tensorflow:5 out of the last 50 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000118973DACA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Action: race: 100%|██████████| 4/4 [00:15<00:00,  4.00s/it]

# %%
predictions['dominant_emotion']
# Out:
# 'happy'

# %%
obj = DeepFace.analyze(img_path = "sadwoman.jpg", actions = ['age', 'gender', 'race', 'emotion'])
# Out:
# Action: emotion: 100%|██████████| 4/4 [00:11<00:00,  2.96s/it]

# %%
print(obj["age"]," years old ",obj["dominant_race"]," ",obj["dominant_emotion"]," ", obj["gender"])
# Out:
# 36  years old  latino hispanic   neutral   Woman

# %%
faceCascade  = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
cv2.CascadeClassifier
# Out:
# cv2.CascadeClassifier

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)

for(x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,
           predictions['dominant_emotion'],
           (0,50),
           font,1,
           (0,0,255),
           2,
           cv2.LINE_4)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[149, 137, 127],
#         [151, 139, 129],
#         [158, 145, 137],
#         ...,
#         [173, 157, 151],
#         [171, 155, 149],
#         [169, 153, 147]],
#
#        [[147, 135, 125],
#         [146, 134, 124],
#         [154, 141, 133],
#         ...,
#         [177, 163, 157],
#         [176, 163, 155],
#         [174, 161, 153]],
#
#        [[143, 131, 121],
#         [143, 131, 121],
#         [151, 138, 130],
#         ...,
#         [178, 164, 158],
#         [178, 165, 157],
#         [179, 166, 158]]], dtype=uint8)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
sad = cv2.imread('sadwoman.jpg')

# %%
predictions  = DeepFace.analyze(sad)
# Out:
# Action: race: 100%|██████████| 4/4 [00:11<00:00,  2.96s/it]

# %%
import cv2
from deepface import DeepFace

faceCascade  = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

cap = cv2.VideoCapture(0)

if not cap.isOpened():
    raise IOError("Cannot open webcam")

while True:
    ret, frame = cap.read()
    result = DeepFace.analyze(frame, actions = ['emotion'])
    
    gray=cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    faces=faceCascade.detectMultiScale(gray,1,1,4)
    
    for(x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(img,
           predictions['dominant_emotion'],
           (50,50),
           font,3,
           (0,255,0),
           2,
           cv2.LINE_4)
    cv2.imshow('Original Video',frame)
    
    if cv2.waitkey(2) & OxFF == ord('q'):
        break
        
cap.release()
cv2.DestroyAllWindows()
# Out:
# Action: emotion:   0%|          | 0/5 [00:00<?, ?it/s]
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000118C00493A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Action: emotion:  20%|██        | 1/5 [00:02<00:09,  2.36s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-407d18b5baf7> in <module>
#      11 while True:
#      12     ret, frame = cap.read()
# ---> 13     result = DeepFace.analyze(frame, actions = ['dominant_emotion'])
#      14
#      15     gray=cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#
# ~\AppData\Roaming\Python\Python38\site-packages\deepface\DeepFace.py in analyze(img_path, actions, models, enforce_detection, detector_backend)
#     369                         if action == 'emotion':
#     370                                 emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']
# --> 371                                 img = functions.preprocess_face(img = img_path, target_size = (48, 48), grayscale = True, enforce_detection = enforce_detection, detector_backend = detector_backend)
#     372
#     373                                 emotion_predictions = models['emotion'].predict(img)[0,:]
#
# ~\AppData\Roaming\Python\Python38\site-packages\deepface\commons\functions.py in preprocess_face(img, target_size, grayscale, enforce_detection, detector_backend)
#     445         base_img = img.copy()
#     446
# --> 447         img = detect_face(img = img, detector_backend = detector_backend, grayscale = grayscale, enforce_detection = enforce_detection)
#     448
#     449         #--------------------------
#
# ~\AppData\Roaming\Python\Python38\site-packages\deepface\commons\functions.py in detect_face(img, detector_backend, grayscale, enforce_detection)
#     310
#     311                         else:
# --> 312                                 raise ValueError("Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.")
#     313
#     314         else:
#
# ValueError: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
